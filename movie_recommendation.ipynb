# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhkrout9/king1/blob/main/movie_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive .mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
columns_name=["user_id","item_id","rating","timestamp"]
df=pd.read_csv('/content/drive/MyDrive/data /movie lems/u.data',sep='\t',names=columns_name)
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
movies_titles=pd.read_csv("/content/drive/MyDrive/data /movie lems/u.item",sep='\|',header=None)

# %%
movies_titles=movies_titles[[0,1]]
movies_titles.columns=['item_id','title']
movies_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df=pd.merge(df,movies_titles,on="item_id")

# %%
df
# Out:
#        user_id  ...                                              title
# 0          196  ...                                       Kolya (1996)
# 1           63  ...                                       Kolya (1996)
# 2          226  ...                                       Kolya (1996)
# 3          154  ...                                       Kolya (1996)
# 4          306  ...                                       Kolya (1996)
# ...        ...  ...                                                ...
# 99995      840  ...                                  Mamma Roma (1962)
# 99996      655  ...                             Eighth Day, The (1996)
# 99997      655  ...                                  Girls Town (1996)
# 99998      655  ...  Silence of the Palace, The (Saimt el Qusur) (1...
# 99999      655  ...                                    Dadetown (1995)
#
# [100000 rows x 5 columns]

# %% [markdown]
# exploratory analysis of data set

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.groupby('title').mean()['rating'].sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title').count()['rating'].sort_values(ascending=False)
# Out:
# title
# Star Wars (1977)                              583
# Contact (1997)                                509
# Fargo (1996)                                  508
# Return of the Jedi (1983)                     507
# Liar Liar (1997)                              485
#                                              ...
# Man from Down Under, The (1943)                 1
# Marlene Dietrich: Shadow and Light (1996)       1
# Mat' i syn (1997)                               1
# Mille bolle blu (1993)                          1
# � k�ldum klaka (Cold Fever) (1994)              1
# Name: rating, Length: 1664, dtype: int64

# %%
ratings=pd.DataFrame(df.groupby('title').mean()['rating'])

# %%
ratings
# Out:
#                                          rating
# title
# 'Til There Was You (1997)              2.333333
# 1-900 (1994)                           2.600000
# 101 Dalmatians (1996)                  2.908257
# 12 Angry Men (1957)                    4.344000
# 187 (1997)                             3.024390
# ...                                         ...
# Young Guns II (1990)                   2.772727
# Young Poisoner's Handbook, The (1995)  3.341463
# Zeus and Roxanne (1997)                2.166667
# unknown                                3.444444
# � k�ldum klaka (Cold Fever) (1994)     3.000000
#
# [1664 rows x 1 columns]

# %%
ratings['number_of_ratings']=pd.DataFrame(df.groupby('title').count()['rating'])

# %%
ratings
# Out:
#                                          rating  number_of_ratings
# title
# 'Til There Was You (1997)              2.333333                  9
# 1-900 (1994)                           2.600000                  5
# 101 Dalmatians (1996)                  2.908257                109
# 12 Angry Men (1957)                    4.344000                125
# 187 (1997)                             3.024390                 41
# ...                                         ...                ...
# Young Guns II (1990)                   2.772727                 44
# Young Poisoner's Handbook, The (1995)  3.341463                 41
# Zeus and Roxanne (1997)                2.166667                  6
# unknown                                3.444444                  9
# � k�ldum klaka (Cold Fever) (1994)     3.000000                  1
#
# [1664 rows x 2 columns]

# %%
ratings.sort_values(by='rating',ascending=False)
# Out:
#                                               rating  number_of_ratings
# title
# They Made Me a Criminal (1939)                   5.0                  1
# Marlene Dietrich: Shadow and Light (1996)        5.0                  1
# Saint of Fort Washington, The (1993)             5.0                  2
# Someone Else's America (1995)                    5.0                  1
# Star Kid (1997)                                  5.0                  3
# ...                                              ...                ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)     1.0                  1
# King of New York (1990)                          1.0                  1
# Touki Bouki (Journey of the Hyena) (1973)        1.0                  1
# Bloody Child, The (1996)                         1.0                  1
# Crude Oasis, The (1995)                          1.0                  1
#
# [1664 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.hist(ratings['number_of_ratings'],bins=70)
plt.show()

# %%
plt.hist(ratings['rating'],bins=70)
plt.show()

# %%
sns.jointplot(x='rating',y='number_of_ratings',data=ratings,alpha=0.5)

# %%
moviemat=df.pivot_table(index='user_id',columns='title',values='rating')

# %%
moviemat
# Out:
# title    'Til There Was You (1997)  ...  � k�ldum klaka (Cold Fever) (1994)
# user_id                             ...
# 1                              NaN  ...                                 NaN
# 2                              NaN  ...                                 NaN
# 3                              NaN  ...                                 NaN
# 4                              NaN  ...                                 NaN
# 5                              NaN  ...                                 NaN
# ...                            ...  ...                                 ...
# 939                            NaN  ...                                 NaN
# 940                            NaN  ...                                 NaN
# 941                            NaN  ...                                 NaN
# 942                            NaN  ...                                 NaN
# 943                            NaN  ...                                 NaN
#
# ...

# %%
ratings.sort_values('number_of_ratings',ascending=False).head()
# Out:
#                              rating  number_of_ratings
# title
# Star Wars (1977)           4.358491                583
# Contact (1997)             3.803536                509
# Fargo (1996)               4.155512                508
# Return of the Jedi (1983)  4.007890                507
# Liar Liar (1997)           3.156701                485

# %%
starwars_user_ratings=moviemat['Star Wars (1977)']
starwars_user_ratings.head()
# Out:
# user_id
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    4.0
# Name: Star Wars (1977), dtype: float64

# %%
similar_to_starwars=moviemat.corrwith(starwars_user_ratings)

# %%
similar_to_starwars
# Out:
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# Young Guns II (1990)                     0.228615
# Young Poisoner's Handbook, The (1995)   -0.007374
# Zeus and Roxanne (1997)                  0.818182
# unknown                                  0.723123
# � k�ldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
corr_starwars=pd.DataFrame(similar_to_starwars,columns=['correlation'])

# %%
similar_to_starwars
# Out:
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# Young Guns II (1990)                     0.228615
# Young Poisoner's Handbook, The (1995)   -0.007374
# Zeus and Roxanne (1997)                  0.818182
# unknown                                  0.723123
# � k�ldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
corr_starwars.dropna(inplace=True)

# %%
corr_starwars.head()
# Out:
#                            correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
corr_starwars.sort_values('correlation',ascending=False).head(10)
# Out:
#                                                     correlation
# title
# Commandments (1997)                                         1.0
# Cosi (1996)                                                 1.0
# No Escape (1994)                                            1.0
# Stripes (1981)                                              1.0
# Man of the Year (1995)                                      1.0
# Hollow Reed (1996)                                          1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Good Man in Africa, A (1994)                                1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0

# %%
corr_starwars=corr_starwars.join(ratings['number_of_ratings'],lsuffix='none')

# %%
ratings
# Out:
#                                          rating  number_of_ratings
# title
# 'Til There Was You (1997)              2.333333                  9
# 1-900 (1994)                           2.600000                  5
# 101 Dalmatians (1996)                  2.908257                109
# 12 Angry Men (1957)                    4.344000                125
# 187 (1997)                             3.024390                 41
# ...                                         ...                ...
# Young Guns II (1990)                   2.772727                 44
# Young Poisoner's Handbook, The (1995)  3.341463                 41
# Zeus and Roxanne (1997)                2.166667                  6
# unknown                                3.444444                  9
# � k�ldum klaka (Cold Fever) (1994)     3.000000                  1
#
# [1664 rows x 2 columns]

# %%
corr_starwars.head()
# Out:
#                            correlation  ...  number_of_ratings
# title                                   ...
# 'Til There Was You (1997)     0.872872  ...                  9
# 1-900 (1994)                 -0.645497  ...                  5
# 101 Dalmatians (1996)         0.211132  ...                109
# 12 Angry Men (1957)           0.184289  ...                125
# 187 (1997)                    0.027398  ...                 41
#
# [5 rows x 3 columns]

# %%
corr_starwars[corr_starwars['number_of_ratings']>100].sort_values('correlation',ascending=False)
# Out:
#                                                     correlation  ...  number_of_ratings
# title                                                            ...
# Star Wars (1977)                                       1.000000  ...                583
# Empire Strikes Back, The (1980)                        0.747981  ...                367
# Return of the Jedi (1983)                              0.672556  ...                507
# Raiders of the Lost Ark (1981)                         0.536117  ...                420
# Austin Powers: International Man of Mystery (1997)     0.377433  ...                130
# ...                                                         ...  ...                ...
# Edge, The (1997)                                      -0.127167  ...                113
# As Good As It Gets (1997)                             -0.130466  ...                112
# Crash (1996)                                          -0.148507  ...                128
# ...

# %% [markdown]
# predict function

# %%
def predict_movies(movie_name):
  movie_user_ratings=moviemat[movie_name]
  similar_to_movie=moviemat.corrwith(movie_user_ratings)
  corr_movie=pd.DataFrame(similar_to_movie,columns=['correlation'])
  corr_movie.dropna(inplace=True)
  corr_movie=corr_movie.join(ratings['number_of_ratings'])
  predictions=corr_movie[corr_movie['number_of_ratings']>100].sort_values('correlation',ascending=False)

  return predictions

# %%
predictions=predict_movies('G.I. Jane (1997)')

# %%
predictions.head()
# Out:
#                                   correlation  number_of_ratings
# title
# G.I. Jane (1997)                     1.000000                175
# Sneakers (1992)                      0.729664                150
# In the Name of the Father (1993)     0.705170                102
# American President, The (1995)       0.697412                164
# Grumpier Old Men (1995)              0.653084                148
